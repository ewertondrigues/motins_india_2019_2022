# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as plt

# %%
filename = '2019-03-19-2022-03-25-South_Asia-India.csv'
df  = pd.read_csv(filename, index_col=0)

# %%
df.head(5)
# Out:
#          iso event_id_cnty  event_id_no_cnty     event_date  year  \
# data_id
# 8912977  356     IND107923          107923.0  18 March 2022  2022
# 8912990  356     IND107846          107846.0  18 March 2022  2022
# 8913012  356     IND107941          107941.0  18 March 2022  2022
# 8913089  356     IND107842          107842.0  18 March 2022  2022
# 8913091  356     IND107850          107850.0  18 March 2022  2022
#
#          time_precision event_type    sub_event_type              actor1  \
# data_id
# 8912977               1      Riots      Mob violence     Rioters (India)
# 8912990               1   Protests  Peaceful protest  Protesters (India)
# 8913012               1   Protests  Peaceful protest  Protesters (India)
# 8913089               1   Protests  Peaceful protest  Protesters (India)
# 8913091               1      Riots      Mob violence     Rioters (India)
#
#                                              assoc_actor_1  ...  \
# ...

# %%
dfAtual = df[['event_date','year','event_type','sub_event_type','sub_event_type','actor1','assoc_actor_1','location','source','notes','fatalities']]
dfAtual.head(3)
# Out:
#             event_date  year event_type    sub_event_type    sub_event_type  \
# data_id
# 8912977  18 March 2022  2022      Riots      Mob violence      Mob violence
# 8912990  18 March 2022  2022   Protests  Peaceful protest  Peaceful protest
# 8913012  18 March 2022  2022   Protests  Peaceful protest  Peaceful protest
#
#                      actor1  \
# data_id
# 8912977     Rioters (India)
# 8912990  Protesters (India)
# 8913012  Protesters (India)
#
#                                              assoc_actor_1  \
# data_id
# 8912977  Singraur Caste Group (India); Rajput Caste Gro...
# 8912990                               Labour Group (India)
# 8913012                                                NaN
#
#                      location                    source  \
# data_id
# 8912977             Kishanpur                Amar Ujala
# 8912990  Mumbai - Azad Maidan  Asian News International
# 8913012             Ahmedgarh        Chandigarh Tribune
#
# ...

# %%
# dfAtual.to_csv('Motins_Atualizados.csv', index=False)

# %% [markdown]
# # Analise Preliminar

# %%
df.count()
# Out:
# iso                 56500
# event_id_cnty       56500
# event_id_no_cnty    56500
# event_date          56500
# year                56500
# time_precision      56500
# event_type          56500
# sub_event_type      56500
# actor1              56500
# assoc_actor_1       43582
# inter1              56500
# actor2              15176
# assoc_actor_2        6487
# inter2              56500
# interaction         56500
# region              56500
# country             56500
# admin1              56500
# admin2              56493
# admin3              55500
# location            56500
# latitude            56500
# longitude           56500
# geo_precision       56500
# source              56500
# source_scale        56500
# notes               56500
# fatalities          56500
# timestamp           56500
# iso3                56500
# dtype: int64

# %%
df2022 =df.loc[df['year'] == 2022]

# %%
df2022.head(3)
# Out:
#          iso event_id_cnty  event_id_no_cnty     event_date  year  \
# data_id
# 8912977  356     IND107923          107923.0  18 March 2022  2022
# 8912990  356     IND107846          107846.0  18 March 2022  2022
# 8913012  356     IND107941          107941.0  18 March 2022  2022
#
#          time_precision event_type    sub_event_type              actor1  \
# data_id
# 8912977               1      Riots      Mob violence     Rioters (India)
# 8912990               1   Protests  Peaceful protest  Protesters (India)
# 8913012               1   Protests  Peaceful protest  Protesters (India)
#
#                                              assoc_actor_1  ...  \
# data_id                                                     ...
# 8912977  Singraur Caste Group (India); Rajput Caste Gro...  ...
# 8912990                               Labour Group (India)  ...
# 8913012                                                NaN  ...
#
# ...

# %%
df2021 = df.loc[df['year'] == 2021]
df2021.head(3)
# Out:
#          iso event_id_cnty  event_id_no_cnty        event_date  year  \
# data_id
# 8761409  356     IND104704          104704.0  31 December 2021  2021
# 8761494  356     IND104696          104696.0  31 December 2021  2021
# 8761604  356     IND104698          104698.0  31 December 2021  2021
#
#          time_precision event_type    sub_event_type              actor1  \
# data_id
# 8761409               1   Protests  Peaceful protest  Protesters (India)
# 8761494               1      Riots      Mob violence     Rioters (India)
# 8761604               1      Riots      Mob violence     Rioters (India)
#
#               assoc_actor_1  ...                location latitude longitude  \
# data_id                      ...
# 8761409                 NaN  ...                   Khour  32.8229   74.5112
# 8761494                 NaN  ...  Delhi - Rajendra Nagar  28.6387   77.1815
# 8761604  Sikh Group (India)  ...               Chuslewar  31.2715   74.7883
#
# ...

# %%
df2020 = df.loc[df['year'] == 2020]
df2020.head(3)
# Out:
#          iso event_id_cnty  event_id_no_cnty        event_date  year  \
# data_id
# 7460424  356      IND87029           87029.0  31 December 2020  2020
# 7460431  356      IND87038           87038.0  31 December 2020  2020
# 7460709  356      IND87046           87046.0  31 December 2020  2020
#
#          time_precision event_type    sub_event_type              actor1  \
# data_id
# 7460424               1   Protests  Peaceful protest  Protesters (India)
# 7460431               1   Protests  Peaceful protest  Protesters (India)
# 7460709               1   Protests  Peaceful protest  Protesters (India)
#
#                                              assoc_actor_1  ...   location  \
# data_id                                                     ...
# 7460424                Labour Group (India); Women (India)  ...   Srinagar
# 7460431  Farmers (India); KMSC: Farm Labourer Struggle ...  ...   Amritsar
# 7460709                                   Teachers (India)  ...  Allahabad
#
# ...

# %%
df2019 = df.loc[df['year'] == 2019]
df2019.head(3)
# Out:
#          iso event_id_cnty  event_id_no_cnty        event_date  year  \
# data_id
# 6714329  356      IND68955           68955.0  31 December 2019  2019
# 6714375  356      IND68961           68961.0  31 December 2019  2019
# 6714400  356      IND68964           68964.0  31 December 2019  2019
#
#          time_precision event_type    sub_event_type              actor1  \
# data_id
# 6714329               1   Protests  Peaceful protest  Protesters (India)
# 6714375               1   Protests  Peaceful protest  Protesters (India)
# 6714400               1   Protests  Peaceful protest  Protesters (India)
#
#                                  assoc_actor_1  ...  location latitude  \
# data_id                                         ...
# 6714329  Farmers (India); JSP: Jana Sena Party  ...  Mandadam  16.5192
# 6714375                   Labour Group (India)  ...    Mahoba  25.2905
# 6714400                    SP: Samajwadi Party  ...   Lucknow  26.8392
#
# ...

# %%
df.loc[df['year'] == 2018]
# Out:
# Empty DataFrame
# Columns: [iso, event_id_cnty, event_id_no_cnty, event_date, year, time_precision, event_type, sub_event_type, actor1, assoc_actor_1, inter1, actor2, assoc_actor_2, inter2, interaction, region, country, admin1, admin2, admin3, location, latitude, longitude, geo_precision, source, source_scale, notes, fatalities, timestamp, iso3]
# Index: []
#
# [0 rows x 30 columns]

# %%
dfCidades = df['location'].unique()
dfCidades
# Out:
# array(['Kishanpur', 'Mumbai - Azad Maidan', 'Ahmedgarh', ..., 'Lathigram',
#        'Erachakulam', 'Mekeri'], dtype=object)

# %%
df2022Atual = df2022[['event_date','year','event_type','sub_event_type','sub_event_type','actor1','assoc_actor_1','location','source','notes','fatalities']]
df2022Atual.head(3)
# Out:
#             event_date  year event_type    sub_event_type    sub_event_type  \
# data_id
# 8912977  18 March 2022  2022      Riots      Mob violence      Mob violence
# 8912990  18 March 2022  2022   Protests  Peaceful protest  Peaceful protest
# 8913012  18 March 2022  2022   Protests  Peaceful protest  Peaceful protest
#
#                      actor1  \
# data_id
# 8912977     Rioters (India)
# 8912990  Protesters (India)
# 8913012  Protesters (India)
#
#                                              assoc_actor_1  \
# data_id
# 8912977  Singraur Caste Group (India); Rajput Caste Gro...
# 8912990                               Labour Group (India)
# 8913012                                                NaN
#
#                      location                    source  \
# data_id
# 8912977             Kishanpur                Amar Ujala
# 8912990  Mumbai - Azad Maidan  Asian News International
# 8913012             Ahmedgarh        Chandigarh Tribune
#
# ...

# %%
df2021Atual = df2021[['event_date','year','event_type','sub_event_type','sub_event_type','actor1','assoc_actor_1','location','source','notes','fatalities']]
df2021Atual.head(3)
# Out:
#                event_date  year event_type    sub_event_type  \
# data_id
# 8761409  31 December 2021  2021   Protests  Peaceful protest
# 8761494  31 December 2021  2021      Riots      Mob violence
# 8761604  31 December 2021  2021      Riots      Mob violence
#
#            sub_event_type              actor1       assoc_actor_1  \
# data_id
# 8761409  Peaceful protest  Protesters (India)                 NaN
# 8761494      Mob violence     Rioters (India)                 NaN
# 8761604      Mob violence     Rioters (India)  Sikh Group (India)
#
#                        location                    source  \
# data_id
# 8761409                   Khour                Amar Ujala
# 8761494  Delhi - Rajendra Nagar  Asian News International
# 8761604               Chuslewar        Chandigarh Tribune
#
#                                                      notes  fatalities
# data_id
# 8761409  On 31 December 2021, locals held a protest at ...           0
# ...

# %%
df2020Atual = df2020[['event_date','year','event_type','sub_event_type','sub_event_type','actor1','assoc_actor_1','location','source','notes','fatalities']]
df2020Atual.head(3)
# Out:
#                event_date  year event_type    sub_event_type  \
# data_id
# 7460424  31 December 2020  2020   Protests  Peaceful protest
# 7460431  31 December 2020  2020   Protests  Peaceful protest
# 7460709  31 December 2020  2020   Protests  Peaceful protest
#
#            sub_event_type              actor1  \
# data_id
# 7460424  Peaceful protest  Protesters (India)
# 7460431  Peaceful protest  Protesters (India)
# 7460709  Peaceful protest  Protesters (India)
#
#                                              assoc_actor_1   location  \
# data_id
# 7460424                Labour Group (India); Women (India)   Srinagar
# 7460431  Farmers (India); KMSC: Farm Labourer Struggle ...   Amritsar
# 7460709                                   Teachers (India)  Allahabad
#
#                                                     source  \
# data_id
# 7460424                    Kashmir Images; Greater Kashmir
# 7460431  Chandigarh Tribune; Indian Express; Asian News...
# ...

# %%
df2019Atual = df2019[['event_date','year','event_type','sub_event_type','sub_event_type','actor1','assoc_actor_1','location','source','notes','fatalities']]
df2019Atual.head(3)
# Out:
#                event_date  year event_type    sub_event_type  \
# data_id
# 6714329  31 December 2019  2019   Protests  Peaceful protest
# 6714375  31 December 2019  2019   Protests  Peaceful protest
# 6714400  31 December 2019  2019   Protests  Peaceful protest
#
#            sub_event_type              actor1  \
# data_id
# 6714329  Peaceful protest  Protesters (India)
# 6714375  Peaceful protest  Protesters (India)
# 6714400  Peaceful protest  Protesters (India)
#
#                                  assoc_actor_1  location  \
# data_id
# 6714329  Farmers (India); JSP: Jana Sena Party  Mandadam
# 6714375                   Labour Group (India)    Mahoba
# 6714400                    SP: Samajwadi Party   Lucknow
#
#                                source  \
# data_id
# 6714329  Bangalore Mirror; Hans India
# 6714375                    Amar Ujala
# 6714400                    Amar Ujala
#
#                                                      notes  fatalities
# data_id
# ...

# %%
dfLocal = df[['location','latitude','longitude']]
dfLocal
# Out:
#                      location  latitude  longitude
# data_id
# 8912977             Kishanpur   25.6422    81.0244
# 8912990  Mumbai - Azad Maidan   18.9388    72.8321
# 8913012             Ahmedgarh   30.6785    75.8272
# 8913089                Indore   22.7179    75.8333
# 8913091               Kanavar   26.5622    78.9797
# ...                       ...       ...        ...
# 8626313            Awantipora   33.9219    75.0136
# 8626314            Awantipora   33.9219    75.0136
# 8626315               Pulwama   33.8741    74.9001
# 8626316                Mekeri   12.3909    75.7337
# 8698803              Duliajan   27.3575    95.3230
#
# [56500 rows x 3 columns]

# %%
dfLocal.to_csv('local_motins.csv', index=False)

# %% [markdown]
# ## Fatalidades

# %%
dfMortes = df[df.fatalities > 0]
dfMortesTotal = dfMortes.fatalities.sum()
dfMortesTotal
# Out:
# 3732

# %%
df2022Mortes = df2022Atual[df2022Atual.fatalities > 0]
df2022MortesTotal = df2022Mortes.fatalities.sum()
df2022MortesTotal
# Out:
# 220

# %%
df2022Mortes.fatalities.max()
# Out:
# 14

# %%
df2021Mortes = df2021Atual[df2021Atual.fatalities > 0]
df2021MortesTotal = df2021Mortes.fatalities.sum()
df2021MortesTotal
# Out:
# 993

# %%
df2021Mortes.fatalities.max()
# Out:
# 31

# %%
df2020Mortes = df2020Atual[df2020Atual.fatalities > 0]
df2020MortesTotal = df2020Mortes.fatalities.sum()
df2020MortesTotal
# Out:
# 1323

# %%
df2020Mortes.fatalities.max()
# Out:
# 58

# %%
df2019Mortes = df2019Atual[df2019Atual.fatalities > 0]
df2019MortesTotal = df2019Mortes.fatalities.sum()
df2019MortesTotal
# Out:
# 1196

# %%
df2019Mortes.fatalities.max()
# Out:
# 16
